# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('winee.csv')
df.sample(5)
# Out:
#       Unnamed: 0  fixed.acidity  citric.acid  sulphates  alcohol
# 1299        1300            7.6         0.00       0.40     10.9
# 635          636            8.7         0.00       0.55      9.7
# 888          889            6.8         0.00       0.56     11.2
# 1364        1365            7.2         0.02       0.53     11.8
# 84            85            6.3         0.48       0.78     10.3

# %%
df = pd.read_csv('winee.csv',usecols=[1,2,4])
# df.columns=['Class label', 'Alcohol', 'Malic acid']
# df=pd.read_csv('g.csv')
df.head()
# Out:
#    fixed.acidity  citric.acid  alcohol
# 0            7.4         0.00      9.4
# 1            7.8         0.00      9.8
# 2            7.8         0.04      9.8
# 3           11.2         0.56      9.8
# 4            7.4         0.00      9.4

# %%
sns.kdeplot(df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['fixed.acidity'])
# Out:
# <Axes: xlabel='fixed.acidity', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
# sns.scatterplot(df['alcohol'],df['fixed.acidity'],hue=df['citric.acid'],palette=color_dict)
sns.scatterplot(data=df,x='alcohol',y='fixed.acidity')
# Out:
# <Axes: xlabel='alcohol', ylabel='fixed.acidity'>
